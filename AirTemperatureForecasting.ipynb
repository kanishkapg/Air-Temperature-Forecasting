# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkapg/Air-Temperature-Forecasting/blob/main/AirTemperatureForecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/ML datasets/jena_climate_2009_2016.csv")

# %%
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df = df[5::6]

# %%
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:25]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
df.columns
# Out:
# Index(['Date Time', 'p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)',
#        'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'wv (m/s)', 'max. wv (m/s)',
#        'wd (deg)'],
#       dtype='object')

# %%
temp = df['T (degC)']
plt.plot(temp)

# %% [markdown]
# ### **Obtaining X and y**

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i+5]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(temp, WINDOW_SIZE)

# %%
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X, y
# Out:
# (array([[[-8.05],
#          [-8.88],
#          [-8.81],
#          [-9.05],
#          [-9.63]],
#
#         [[-8.88],
#          [-8.81],
#          [-9.05],
#          [-9.63],
#          [-9.67]],
#
#         [[-8.81],
#          [-9.05],
#          [-9.63],
#          [-9.67],
#          [-9.17]],
#
#         ...,
#
#         [[ 2.44],
#          [ 1.29],
#          [-0.42],
#          [-0.98],
#          [-1.4 ]],
#
#         [[ 1.29],
#          [-0.42],
#          [-0.98],
#          [-1.4 ],
#          [-2.75]],
#
#         [[-0.42],
#          [-0.98],
#          [-1.4 ],
#          [-2.75],
#          [-2.89]]]),
#  array([-9.67, -9.17, -8.1 , ..., -2.75, -2.89, -3.93]))

# %% [markdown]
# ### **Splitting dataset**

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

# %%
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp = ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()] )

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, callbacks=[cp])
# Out:
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 71.9484 - root_mean_squared_error: 8.2555 - val_loss: 1.3657 - val_root_mean_squared_error: 1.1687
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 2.9737 - root_mean_squared_error: 1.7155 - val_loss: 0.6015 - val_root_mean_squared_error: 0.7756
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.0093 - root_mean_squared_error: 1.0041 - val_loss: 0.5681 - val_root_mean_squared_error: 0.7537
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.7635 - root_mean_squared_error: 0.8736 - val_loss: 0.5102 - val_root_mean_squared_error: 0.7143
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.7128 - root_mean_squared_error: 0.8441 - val_loss: 0.5086 - val_root_mean_squared_error: 0.7131
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.6652 - root_mean_squared_error: 0.8155 - val_loss: 0.5083 - val_root_mean_squared_error: 0.7130
# ...

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1.keras')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions': train_predictions, 'Actuals': y_train})
train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#        Train Predictions  Actuals
# 0              -9.808534    -9.67
# 1              -9.597699    -9.17
# 2              -8.670340    -8.10
# 3              -7.160638    -7.66
# 4              -7.030096    -7.04
# ...                  ...      ...
# 59995           6.072738     6.07
# 59996           7.112389     9.88
# 59997          12.081855    13.53
# 59998          15.414000    15.43
# 59999          16.319666    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][:100])
plt.plot(train_results['Actuals'][:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'val Predictions': val_predictions, 'Actuals': y_val})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#       val Predictions  Actuals
# 0           15.633992    14.02
# 1           13.350716    13.67
# 2           13.044366    12.27
# 3           11.471710    11.19
# 4           10.398787    10.85
# ...               ...      ...
# 4995        17.453087    18.27
# 4996        17.495468    17.85
# 4997        17.213812    16.65
# 4998        15.865579    15.85
# 4999        15.104518    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions': test_predictions, 'Actuals': y_test})
test_results
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Test Predictions  Actuals
# 0            14.418005    13.99
# 1            13.248647    13.46
# 2            12.902986    12.93
# 3            12.485287    12.43
# 4            12.034150    12.17
# ...                ...      ...
# 5081         -1.089493    -0.98
# 5082         -1.381181    -1.40
# 5083         -1.616199    -2.75
# 5084         -3.209796    -2.89
# 5085         -3.086341    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])
